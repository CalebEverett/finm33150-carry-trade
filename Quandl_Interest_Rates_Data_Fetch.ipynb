# %% [markdown]
# # Using Python With Quandl Data

# %% [markdown]
# ### Preliminaries

# %%
# %matplotlib inline

# %% [markdown]
# Import Python modules to support our research.  If you are using _Anaconda_ then you may need to run _conda install seaborn_ and similar commands.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy as sp
import quandl
import functools
#import seaborn as sns

# %% [markdown]
# ### Load the Data

# %% [markdown]
# We are likely to run this notebook over and over, so we add memoizaiton to the data loading function. This makes testing and re-running our code far faster, and even lets us work offline.  Note that if we change the code inside our function, we may get unexpectedly stale results out of the cache!

# %%
@functools.lru_cache(maxsize=16)
def fetch_quandl(s):
    print("Fetching from Quandl")
    qdata = quandl.get(s, returns="pandas")
    return qdata

# %% [markdown]
# ### Different download techniques can give different results

# %%
raw_data = quandl.get('YC/NZL', start_date='2011-01-01', 
                      end_date='2018-04-25', returns="pandas",
                     api_key=BrianBoonstraPrivateKeys['Quandl'])

# %%
raw_data.tail().transpose()
# Out:
# Date     2018-04-18  2018-04-19  2018-04-20  2018-04-23  2018-04-24
# 1-Month        1.87        1.87        1.87        1.87        1.87
# 2-Month        1.96        1.97        1.97        1.96        1.96
# 3-Month        2.05        2.06        2.06        2.05        2.04
# 1-Year         1.79        1.81        1.81        1.81        1.81
# 2-Year         1.93        1.95        1.96        1.96        1.95
# 5-Year         2.37        2.40        2.41        2.43        2.45
# 10-Year        2.82        2.85        2.86        2.90        2.93

# %%
raw_data.plot()

# %%
raw_data['3-Month'].plot()

# %%
m3 = quandl.get('YC/NZL3M', start_date='2011-01-01', 
                      end_date='2018-04-25', returns="pandas",
                     api_key=BrianBoonstraPrivateKeys['Quandl'])
print(m3.tail())
m3.plot()
# Out:
#             Rate
# Date
# 2018-04-18  2.05
# 2018-04-19  2.06
# 2018-04-20  2.06
# 2018-04-23  2.05
# 2018-04-24  2.04
